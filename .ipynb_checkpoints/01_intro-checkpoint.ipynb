# %% [markdown]
# # <center>Introduction to BookNLP</center>

# %% [markdown]
# <center>Dr. W.J.B. Mattingly</center>
#
# <center>Smithsonian Data Science Lab and United States Holocaust Memorial Museum</center>
#
# <center>March 2022</center>

# %% [markdown]
# ## Key Concepts in this Notebook

# %% [markdown]
# 1) What is BookNLP?<br>
# 2) How to Install BookNLP<br>

# %% [markdown]
# ## About the Author

# %% [markdown]
# I am Dr. William Mattingly. I hold a PhD in Medieval History from the University of Kentucky where I explored early medieval social networks. A lot of my research was aided by my ability to code, specifically in Python, for data cleaning and analysis. I was even able to use Python to plot and visualize social networks and data. During the fourth year of my PhD, I used Python to create an app that I could use to plot and analyze these social networks. Currently, I am a Postdoctoral Fellow for the Analysis of Historical Documents at the Smithsonian Institution with a joint appointment at the United States Holocaust Memorial Museum. In both institutions, I use Python, machine learning, and natural language processing (NLP) to analyze historical texts in large quantities to generate new insights about the documents held in the archives. In all, I have nearly a decade of experience using Python as a historian.
#
# When I first started to explore Python, there were not many available tutorials geared towards humanists and, for that reason, four years ago I started PythonHumanities.com and Python Tutorials for Digital Humanities on YouTube. I geared these resources to humanists who had no prior knowledge about computing or coding. This new JupyterBook is the third iteration of this textbook that brings a lot of the material that first appeared on PythonHumanities.com years ago into a new, more accessible JupyterBook. It will forever remain free to all as will the video lectures embedded in this book.

# %% [markdown]
# ## About this Textbook

# %% [markdown]
# Because this textbook is not peer-reviewed, typos may remain or errors may exist. I openly and freely admit to this. This textbook is community-inspired and I would like it to be community-supported. If you see a mistake, you can click thee GitHub logo inn the top right corner of the screen to submit a pull request or make a note for edits. I highly encourage this and I am open to and welcome any criticism to improve this textbook for all.

# %% [markdown]
# ```{image} ./images/install/github_logo.JPG
# :alt: jupyter_org
# :class: bg-primary
# :width: 500px
# :align: center
# ```

# %% [markdown]
# ## What is BookNLP?

# %% [markdown]
# <a href="https://github.com/booknlp/booknlp">BookNLP</a> is a new Python library created by <a href="https://github.com/dbamman">David Bamman</a>. It was originally created as a Java library in 2014 under the same name, <a href="https://github.com/dbamman/book-nlp">BookNLP</a> by David Bamman, Ted Underwood, and Noah Smith (see, David Bamman, Ted Underwood and Noah Smith, "A Bayesian Mixed Effects Model of Literary Character," ACL 2014). While Java is a powerful coding language, both in speed and ease-of-use, not many digital humanists code in Java primarily. I suspect (I want to emphasize I could be wrong) the reason for the Python library was to address the larger Python-coding community both in general and specifically within the digital humanities. This textbook will deal strictly with the Python library.
#
# In the documentation, Bamman states:
#
# "BookNLP is a natural language processing pipeline that scales to books and other long documents (in English), including:
#
# - Part-of-speech tagging
# - Dependency parsing
# - Entity recognition
# - Character name clustering (e.g., "Tom", "Tom Sawyer", "Mr. Sawyer", "Thomas Sawyer" -> TOM_SAWYER) and coreference resolution
# - Quotation speaker identification
# - Supersense tagging (e.g., "animal", "artifact", "body", "cognition", etc.)
# - Event tagging
# - Referential gender inference (TOM_SAWYER -> he/him/his)"
#
# Unlike its predecessor, the Java library, the Python library leverages the Python NLP library, spaCy, and the Python Transformer library from HuggingFace, rathern than Stanford, to perform many of these tasks. In the last few years, spaCy has proven itself as a dominate force within the NLP community, outperforming many of its predecessors in accuracy and at sacle
#
# It delivers in all these areas.

# %%
from booknlp.booknlp import BookNLP

# %%
model_params={
        "pipeline":"entity,quote,supersense,event,coref",
        "model":"big"}

# %%
booknlp=BookNLP("en", model_params)
# Out:
# {'pipeline': 'entity,event', 'model': 'big'}
# --- startup: 2.055 seconds ---

# %%
# Input file to process
input_file="harry_potter.txt"

# Output directory to store resulting files in
output_directory="harry_potter"

# File within this directory will be named ${book_id}.entities, ${book_id}.tokens, etc.
book_id="harry_potter"
booknlp.process(input_file, output_directory, book_id)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19764/2539866958.py in <module>
#       7 # File within this directory will be named ${book_id}.entities, ${book_id}.tokens, etc.
#       8 book_id="harry_potter"
# ----> 9 booknlp.process(input_file, output_directory, book_id)
#
# ~\anaconda3\envs\booknlp\lib\site-packages\booknlp\booknlp.py in process(self, inputFile, outputFolder, idd)
#      15
#      16         def process(self, inputFile, outputFolder, idd):
# ---> 17                 self.booknlp.process(inputFile, outputFolder, idd)
#      18
#      19
#
# AttributeError: 'BookNLP' object has no attribute 'booknlp'

# %%
import json
from collections import Counter

# %%
def proc(filename):
    with open(filename) as file:
        data=json.load(file)
    return data

# %%
data=proc("harry_potter/harry_potter.book")

# %%
def get_counter_from_dependency_list(dep_list):
    counter=Counter()
    for token in dep_list:
        term=token["w"]
        tokenGlobalIndex=token["i"]
        counter[term]+=1
    return counter

# %%
for character in data["characters"]:
    agentList=character["agent"]
    patientList=character["patient"]
    possList=character["poss"]
    modList=character["mod"]
    
    character_id=character["id"]
    count=character["count"]

    referential_gender_distribution=referential_gender_prediction="unknown"

    if character["g"] is not None and character["g"] != "unknown":
        referential_gender_distribution=character["g"]["inference"]
        referential_gender=character["g"]["argmax"]

    mentions=character["mentions"]
    proper_mentions=mentions["proper"]
    max_proper_mention=""

    # just print out information about named characters
    if len(mentions["proper"]) > 0:
        max_proper_mention=mentions["proper"][0]["n"]
        
        print(character_id, count, max_proper_mention, referential_gender)

        print()
        printTop=10
        for k, v in get_counter_from_dependency_list(possList).most_common(printTop):
            print("\tposs\t%s %s" % (v,k))
        print()
        for k, v in get_counter_from_dependency_list(agentList).most_common(printTop):
            print("\tagent\t%s %s" % (v,k))        
        print()
        for k, v in get_counter_from_dependency_list(patientList).most_common(printTop):
            print("\tpatient\t%s %s" % (v,k))       
        print()
        for k, v in get_counter_from_dependency_list(modList).most_common(printTop):
            print("\tmod\t%s %s" % (v,k))    
        print()
# Out:
# 95 2022 Harry he/him/his
#
# 	poss	18 head
# 	poss	15 eyes
# 	poss	12 cupboard
# 	poss	12 hand
# 	poss	11 life
# 	poss	10 parents
# 	poss	9 aunt
# 	poss	9 mind
# 	poss	8 heart
# 	poss	7 uncle
#
# 	agent	91 said
# 	agent	43 had
# 	agent	29 know
# 	agent	22 felt
# 	agent	21 got
# 	agent	21 saw
# 	agent	20 looked
# 	agent	20 going
# 	agent	17 heard
# 	agent	17 have
#
# 	patient	11 told
# 	patient	5 take
# 	patient	5 asked
# 	patient	4 kill
# 	patient	4 reminded
# 	patient	4 got
# 	patient	3 took
# 	patient	3 caught
# 	patient	3 tell
# 	patient	2 left
#
# 	mod	9 sure
# 	mod	5 able
# 	mod	3 glad
# 	mod	2 name
# 	mod	2 famous
# 	mod	2 surprised
# 	mod	2 baby
# 	mod	2 stupid
# 	mod	2 afraid
# 	mod	2 safe
#
# 282 1594 Hagrid he/him/his
#
# 	poss	13 head
# 	poss	11 face
# 	poss	8 feet
# 	poss	7 eyes
# 	poss	7 hand
# 	poss	6 coat
# 	poss	6 broom
# 	poss	5 parents
# 	poss	5 back
# 	poss	5 hut
#
# 	agent	166 said
# 	agent	24 looked
# 	agent	23 told
# 	agent	20 know
# 	agent	19 had
# 	agent	18 got
# 	agent	13 pulled
# 	agent	10 knew
# 	agent	10 think
# 	agent	10 see
#
# 	patient	12 told
# 	patient	7 tell
# 	patient	5 followed
# 	patient	4 trust
# 	patient	4 see
# 	patient	4 telling
# 	patient	4 ask
# 	patient	3 follow
# 	patient	3 See
# 	patient	2 reminds
#
# 	mod	4 right
# 	mod	3 about
# 	mod	3 famous
# 	mod	3 sure
# 	mod	2 tall
# 	mod	2 ter
# 	mod	2 sort
# 	mod	2 gamekeeper
# 	mod	2 brilliant
# 	mod	2 fine
#
# 109 1010 Harry he/him/his
#
# 	poss	7 eyes
# 	poss	7 broom
# 	poss	6 wand
# 	poss	5 head
# 	poss	5 father
# 	poss	4 forehead
# 	poss	4 hand
# 	poss	4 hands
# 	poss	4 family
# 	poss	3 plate
#
# 	agent	46 said
# 	agent	21 had
# 	agent	16 looked
# 	agent	15 going
# 	agent	14 see
# 	agent	11 thought
# 	agent	10 know
# 	agent	10 saw
# 	agent	9 pulled
# 	agent	9 whispered
#
# 	patient	3 tell
# 	patient	3 stop
# 	patient	2 told
# 	patient	2 followed
# 	patient	2 follow
# 	patient	2 show
# 	patient	2 see
# 	patient	2 catch
# 	patient	1 bring
# 	patient	1 cried
#
# 	mod	4 able
# 	mod	3 good
# 	mod	3 busy
# 	mod	2 sure
# 	mod	2 right
# 	mod	2 wrong
# 	mod	2 speechless
# 	mod	1 surprised
# 	mod	1 nervous
# 	mod	1 ghost
#
# 194 901 Ron he/him/his
#
# 	poss	9 wand
# 	poss	6 hand
# 	poss	6 brothers
# 	poss	5 eyes
# 	poss	3 nose
# 	poss	3 ears
# 	poss	3 face
# 	poss	3 head
# 	poss	3 family
# 	poss	2 dad
#
# 	agent	109 said
# 	agent	17 think
# 	agent	17 know
# 	agent	16 got
# 	agent	12 looked
# 	agent	12 had
# 	agent	10 pulled
# 	agent	7 muttered
# 	agent	7 whispered
# 	agent	6 heard
#
# 	patient	9 told
# 	patient	4 asked
# 	patient	3 bit
# 	patient	2 found
# 	patient	2 tell
# 	patient	2 knocked
# 	patient	2 followed
# 	patient	2 ask
# 	patient	2 see
# 	patient	2 ignored
#
# 	mod	3 sure
# 	mod	2 delighted
# 	mod	2 second
# 	mod	2 right
# 	mod	1 tall
# 	mod	1 interested
# 	mod	1 short
# 	mod	1 pale
# 	mod	1 green
# 	mod	1 wrong
#
# 219 575 Hermione she/her
#
# 	poss	5 seat
# 	poss	5 hand
# 	poss	5 wand
# 	poss	4 arms
# 	poss	3 head
# 	poss	3 temper
# 	poss	3 notes
# 	poss	2 mouth
# 	poss	2 face
# 	poss	2 feet
#
# 	agent	59 said
# 	agent	10 got
# 	agent	9 know
# 	agent	7 had
# 	agent	6 started
# 	agent	6 took
# 	agent	6 looked
# 	agent	4 found
# 	agent	4 suppose
# 	agent	4 stood
#
# 	patient	8 told
# 	patient	2 taken
# 	patient	2 asked
# 	patient	1 help
# 	patient	1 try
# 	patient	1 ignored
# 	patient	1 tell
# 	patient	1 dragged
# 	patient	1 stand
# 	patient	1 heard
#
# 	mod	3 sorry
# 	mod	1 dunderhead
# 	mod	1 nervous
# 	mod	1 right
# 	mod	1 angrier
# 	mod	1 nightmare
# 	mod	1 about
# 	mod	1 flat
# 	mod	1 dead
# 	mod	1 person
#
# 265 321 Snape he/him/his
#
# 	poss	5 leg
# 	poss	3 eyes
# 	poss	3 robes
# 	poss	2 cloak
# 	poss	2 face
# 	poss	2 refereeing
# 	poss	1 Head
# 	poss	1 lips
# 	poss	1 wand
# 	poss	1 lesson
#
# 	agent	11 said
# 	agent	6 got
# 	agent	6 trying
# 	agent	5 seemed
# 	agent	5 going
# 	agent	4 know
# 	agent	3 have
# 	agent	3 left
# 	agent	3 tried
# 	agent	2 look
#
# 	patient	5 saw
# 	patient	1 watched
# 	patient	1 snarled
# 	patient	1 look
# 	patient	1 Search
# 	patient	1 showed
# 	patient	1 made
# 	patient	1 hurting
# 	patient	1 ask
# 	patient	1 bit
#
# 	mod	1 pleased
# 	mod	1 mine
# 	mod	1 horrible
# 	mod	1 alone
# 	mod	1 worried
#
# 197 280 Neville he/him/his
#
# 	poss	7 toad
# 	poss	5 face
# 	poss	4 legs
# 	poss	2 hands
# 	poss	2 head
# 	poss	2 arms
# 	poss	2 grandmother
# 	poss	2 broomstick
# 	poss	2 voice
# 	poss	2 feet
#
# 	agent	8 said
# 	agent	4 got
# 	agent	4 go
# 	agent	3 managed
# 	agent	3 forgotten
# 	agent	2 fell
# 	agent	2 had
# 	agent	2 thought
# 	agent	2 tell
# 	agent	2 look
#
# 	patient	4 tell
# 	patient	2 leading
# 	patient	1 called
# 	patient	1 brought
# 	patient	1 catch
# 	patient	1 pushed
# 	patient	1 hanging
# 	patient	1 Take
# 	patient	1 let
# 	patient	1 tells
#
# 	mod	2 worth
# 	mod	1 all-
# 	mod	1 magic
# 	mod	1 bent
# 	mod	1 double
# 	mod	1 wheezing
# 	mod	1 brave
# 	mod	1 poorer
# 	mod	1 cold
# 	mod	1 ready
#
# 121 254 Uncle Vernon he/him/his
#
# 	poss	5 face
# 	poss	2 newspaper
# 	poss	2 seat
# 	poss	2 car
# 	poss	2 hand
# 	poss	2 mustache
# 	poss	2 hands
# 	poss	2 courage
# 	poss	1 subjects
# 	poss	1 knuckles
#
# 	agent	20 said
# 	agent	5 shouted
# 	agent	4 made
# 	agent	3 had
# 	agent	3 got
# 	agent	3 tried
# 	agent	3 grunted
# 	agent	2 looked
# 	agent	2 chuckled
# 	agent	2 warning
#
# 	patient	2 warning
# 	patient	1 handed
# 	patient	1 sneered
# 	patient	1 croaked
# 	patient	1 roared
# 	patient	1 took
# 	patient	1 grabbed
# 	patient	1 brought
# 	patient	1 yelled
# 	patient	1 flattened
#
# 	mod	1 angry
# 	mod	1 armed
# 	mod	1 gettin
# 	mod	1 powerful
# 	mod	1 time
# 	mod	1 back
# 	mod	1 right
#
# 98 234 Dudley he/him/his
#
# 	poss	7 mother
# 	poss	6 father
# 	poss	5 gang
# 	poss	4 stick
# 	poss	3 birthday
# 	poss	2 presents
# 	poss	2 head
# 	poss	2 face
# 	poss	2 computer
# 	poss	2 uniform
#
# 	agent	6 said
# 	agent	5 wanted
# 	agent	5 had
# 	agent	3 have
# 	agent	3 get
# 	agent	2 looked
# 	agent	2 sat
# 	agent	2 want
# 	agent	2 hit
# 	agent	2 stood
#
# 	patient	3 want
# 	patient	2 bought
# 	patient	2 took
# 	patient	1 gossiped
# 	patient	1 kiss
# 	patient	1 put
# 	patient	1 catch
# 	patient	1 watched
# 	patient	1 take
# 	patient	1 leave
#
# 	mod	1 baby
# 	mod	1 fat
# 	mod	1 exercise
# 	mod	1 bigger
# 	mod	1 stupidest
# 	mod	1 leader
# 	mod	1 hungry
# 	mod	1 famous
# 	mod	1 scared
#
# 169 223 Quirrell he/him/his
#
# 	poss	7 turban
# 	poss	5 face
# 	poss	3 hands
# 	poss	2 fingers
# 	poss	2 master
# 	poss	2 head
# 	poss	2 hand
# 	poss	1 's
# 	poss	1 job
# 	poss	1 lessons
#
# 	agent	10 said
# 	agent	3 talking
# 	agent	3 do
# 	agent	3 reached
# 	agent	3 let
# 	agent	3 touch
# 	agent	2 want
# 	agent	2 met
# 	agent	2 went
# 	agent	2 did
#
# 	patient	2 got
# 	patient	2 suspected
# 	patient	2 stop
# 	patient	2 saw
# 	patient	2 keep
# 	patient	1 stammered
# 	patient	1 protected
# 	patient	1 knocked
# 	patient	1 followed
# 	patient	1 interrupted
#
# 	mod	1 weak
# 	mod	1 full
# 	mod	1 wrong
#
# 224 200 Malfoy he/him/his
#
# 	poss	2 name
# 	poss	2 father
# 	poss	2 family
# 	poss	2 friends
# 	poss	2 face
# 	poss	1 hand
# 	poss	1 cheeks
# 	poss	1 wish
# 	poss	1 head
# 	poss	1 slugs
#
# 	agent	15 said
# 	agent	4 looked
# 	agent	4 going
# 	agent	3 turned
# 	agent	3 think
# 	agent	2 held
# 	agent	2 take
# 	agent	2 go
# 	agent	2 got
# 	agent	2 dropped
#
# 	patient	3 met
# 	patient	3 get
# 	patient	2 face
# 	patient	1 sloped
# 	patient	1 told
# 	patient	1 Give
# 	patient	1 knock
# 	patient	1 struck
# 	patient	1 chickened
# 	patient	1 tipped
#
# 	mod	1 careful
# 	mod	1 quick
# 	mod	1 late
# 	mod	1 unpleasant
# 	mod	1 family
#
# 96 181 Mr. Dursley he/him/his
#
# 	poss	5 mind
# 	poss	2 car
# 	poss	2 office
# 	poss	1 sister
# 	poss	1 tie
# 	poss	1 chair
# 	poss	1 briefcase
# 	poss	1 head
# 	poss	1 mirror
# 	poss	1 fingers
#
# 	agent	6 thought
# 	agent	4 had
# 	agent	3 seen
# 	agent	3 sat
# 	agent	3 fell
# 	agent	3 see
# 	agent	3 said
# 	agent	2 gossiped
# 	agent	2 picked
# 	agent	2 tried
#
# 	patient	2 hugged
# 	patient	1 LIVED
# 	patient	1 chortled
# 	patient	1 struck
# 	patient	1 flooded
# 	patient	1 disturb
# 	patient	1 worrying
# 	patient	1 called
# 	patient	1 rattled
# 	patient	1 pull
#
# 	mod	3 sure
# 	mod	1 director
# 	mod	1 man
# 	mod	1 thin
# 	mod	1 blonde
# 	mod	1 enraged
# 	mod	1 worried
# 	mod	1 wrong
#
# 108 167 Dumbledore he/him/his
#
# 	poss	3 cloak
# 	poss	3 pocket
# 	poss	2 arms
# 	poss	1 name
# 	poss	1 boots
# 	poss	1 earmuffs
# 	poss	1 head
# 	poss	1 glasses
# 	poss	1 knee
# 	poss	1 eyes
#
# 	agent	21 said
# 	agent	6 know
# 	agent	3 sat
# 	agent	3 took
# 	agent	2 seem
# 	agent	2 turned
# 	agent	2 smiling
# 	agent	2 have
# 	agent	2 think
# 	agent	1 arrived
#
# 	patient	1 watched
# 	patient	1 amuse
# 	patient	1 watching
# 	patient	1 thank
# 	patient	1 flatter
# 	patient	1 told
# 	patient	1 disappeared
# 	patient	1 stopped
# 	patient	1 seemed
# 	patient	1 had
#
# 	mod	2 mad
# 	mod	1 fond
# 	mod	1 different
# 	mod	1 noble
# 	mod	1 right
# 	mod	1 famous
# 	mod	1 genius
#
# 118 102 Dumbledore he/him/his
#
# 	poss	3 wand
# 	poss	2 eyes
# 	poss	1 heel
# 	poss	1 cloak
# 	poss	1 feet
# 	poss	1 chair
# 	poss	1 time
# 	poss	1 hand
#
# 	agent	9 said
# 	agent	4 see
# 	agent	2 turned
# 	agent	2 gave
# 	agent	1 expect
# 	agent	1 walked
# 	agent	1 clicked
# 	agent	1 sped
# 	agent	1 make
# 	agent	1 murmured
#
# 	patient	1 asked
# 	patient	1 cried
# 	patient	1 informed
# 	patient	1 see
# 	patient	1 See
# 	patient	1 gone
# 	patient	1 got
#
# 	mod	1 serious
# 	mod	1 wizard
#
# 97 95 the Dursleys they/them/their
#
# 	poss	3 house
# 	poss	2 hats
# 	poss	1 opinion
# 	poss	1 fear
# 	poss	1 window
# 	poss	1 nephew
# 	poss	1 door
# 	poss	1 room
# 	poss	1 car
# 	poss	1 hobby
#
# 	agent	7 had
# 	agent	4 bought
# 	agent	2 think
# 	agent	2 knew
# 	agent	2 seen
# 	agent	2 got
# 	agent	2 went
# 	agent	2 do
# 	agent	1 was
# 	agent	1 wanted
#
# 	patient	2 telling
# 	patient	1 blame
# 	patient	1 understand
# 	patient	1 rushed
# 	patient	1 wake
# 	patient	1 s
# 	patient	1 cost
#
# 	mod	1 careful
# 	mod	1 asleep
# 	mod	1 family
#
# 106 87 Aunt Petunia she/her
#
# 	poss	1 voice
# 	poss	1 head
# 	poss	1 Dudleykins
# 	poss	1 lips
# 	poss	1 goodness
# 	poss	1 processor
# 	poss	1 sister
# 	poss	1 mother
# 	poss	1 father
#
# 	agent	10 said
# 	agent	2 went
# 	agent	2 snapped
# 	agent	2 leave
# 	agent	2 left
# 	agent	2 took
# 	agent	2 made
# 	agent	1 thought
# 	agent	1 get
# 	agent	1 scented
#
# 	patient	2 asked
# 	patient	1 asking
# 	patient	1 informed
# 	patient	1 clutched
# 	patient	1 handed
# 	patient	1 hear
# 	patient	1 answer
# 	patient	1 Pulling
#
# 	mod	1 awake
#
# 338 87 Norbert he/him/his
#
# 	poss	1 stutter
# 	poss	1 fangs
# 	poss	1 boot
# 	poss	1 teddy
# 	poss	1 head
# 	poss	1 crate
# 	poss	1 voice
# 	poss	1 turban
# 	poss	1 footsteps
# 	poss	1 spell
#
# 	agent	2 going
# 	agent	2 got
# 	agent	1 seem
# 	agent	1 look
# 	agent	1 cracked
# 	agent	1 bitten
# 	agent	1 packed
# 	agent	1 gets
# 	agent	1 thrashing
# 	agent	1 whispered
#
# 	patient	2 got
# 	patient	2 kill
# 	patient	2 save
# 	patient	1 passed
# 	patient	1 keep
# 	patient	1 dump
# 	patient	1 send
# 	patient	1 put
# 	patient	1 feed
# 	patient	1 get
#
# 	mod	1 baby
# 	mod	1 pale
# 	mod	1 about
# 	mod	1 bad
#
# 211 86 Dumbledore he/him/his
#
# 	poss	2 name
# 	poss	1 wizard
# 	poss	1 defeat
# 	poss	1 work
# 	poss	1 partner
# 	poss	1 come
# 	poss	1 face
# 	poss	1 one
# 	poss	1 wife
# 	poss	1 possession
#
# 	agent	3 said
# 	agent	2 had
# 	agent	2 agreed
# 	agent	2 smiled
# 	agent	2 sighed
# 	agent	1 done
# 	agent	1 missing
# 	agent	1 swapped
# 	agent	1 chuckling
# 	agent	1 read
#
# 	patient	2 find
# 	patient	2 finding
# 	patient	2 found
# 	patient	1 mentioned
# 	patient	1 get
# 	patient	1 read
# 	patient	1 asked
# 	patient	1 help
# 	patient	1 forgive
# 	patient	1 contact
#
# 	mod	1 right
# 	mod	1 one
# 	mod	1 famous
# 	mod	1 recent
#
# 290 80 Wood he/him/his
#
# 	poss	1 expression
# 	poss	1 dreams
# 	poss	1 captain
# 	poss	1 arm
# 	poss	1 eyes
# 	poss	1 pocket
# 	poss	1 homework
# 	poss	1 becoming
# 	poss	1 mastered
# 	poss	1 eye
#
# 	agent	13 said
# 	agent	3 told
# 	agent	2 going
# 	agent	2 took
# 	agent	1 turned
# 	agent	1 looking
# 	agent	1 asked
# 	agent	1 say
# 	agent	1 skipping
# 	agent	1 arrived
#
# 	patient	1 borrow
# 	patient	1 told
# 	patient	1 found
# 	patient	1 Follow
#
# 	mod	1 build
# 	mod	1 delighted
# 	mod	1 surprised
# 	mod	1 busy
#
# 230 77 Peeves he/him/his
#
# 	poss	2 eyes
# 	poss	2 mistake
# 	poss	1 tongue
# 	poss	1 good
# 	poss	1 shouts
# 	poss	1 voice
#
# 	agent	6 said
# 	agent	3 say
# 	agent	2 swooped
# 	agent	2 get
# 	agent	2 see
# 	agent	1 whispered
# 	agent	1 want
# 	agent	1 stuck
# 	agent	1 vanished
# 	agent	1 drop
#
# 	patient	1 show
# 	patient	1 met
# 	patient	1 Told
# 	patient	1 caught
# 	patient	1 see
# 	patient	1 have
#
# 	mod	1 invisible
#
# 191 65 Percy he/him/his
#
# 	poss	2 head
# 	poss	2 brother
# 	poss	1 voice
# 	poss	1 element
# 	poss	1 orders
# 	poss	1 presents
# 	poss	1 arm
# 	poss	1 glasses
# 	poss	1 arms
# 	poss	1 side
#
# 	agent	6 said
# 	agent	1 coming
# 	agent	1 talking
# 	agent	1 hope
# 	agent	1 asked
# 	agent	1 think
# 	agent	1 led
# 	agent	1 took
# 	agent	1 whispered
# 	agent	1 raised
#
# 	patient	3 asked
# 	patient	1 followed
# 	patient	1 barked
# 	patient	1 Follow
# 	patient	1 Excuse
# 	patient	1 saw
# 	patient	1 heard
#
# 	mod	3 prefect
# 	mod	1 interested
#
# 113 58 Voldemort he/him/his
#
# 	poss	1 name
# 	poss	1 yells
# 	poss	1 followers
# 	poss	1 enemies
# 	poss	1 return
#
# 	agent	2 coming
# 	agent	2 killed
# 	agent	2 want
# 	agent	2 has
# 	agent	1 had
# 	agent	1 went
# 	agent	1 waiting
# 	agent	1 thought
# 	agent	1 hear
# 	agent	1 kill
#
# 	patient	1 saying
# 	patient	1 had
# 	patient	1 shrieked
# 	patient	1 screeched
# 	patient	1 Call
# 	patient	1 killed
# 	patient	1 delayed
# 	patient	1 stop
# 	patient	1 face
#
# 	mod	1 frightened
# 	mod	1 able
#
# 179 46 Slytherin he/him/his
#
# 	poss	1 nose
# 	poss	1 's
#
# 	agent	2 goes
# 	agent	1 help
# 	agent	1 looked
# 	agent	1 had
# 	agent	1 gains
# 	agent	1 going
# 	agent	1 take
# 	agent	1 ducks
# 	agent	1 kills
# 	agent	1 blocked
#
# 	patient	2 overtake
# 	patient	1 overtaking
# 	patient	1 showing
#
#
# 192 46 Fred he/him/his
#
# 	poss	1 hair
#
# 	agent	6 said
# 	agent	2 think
# 	agent	1 know
# 	agent	1 dare
# 	agent	1 going
# 	agent	1 came
# 	agent	1 spotted
# 	agent	1 tell
# 	agent	1 disappeared
# 	agent	1 told
#
# 	patient	1 forbid
# 	patient	1 kill
# 	patient	1 heard
# 	patient	1 followed
# 	patient	1 watch
# 	patient	1 having
#
# 	mod	1 right
#
# 185 42 Mr. Ollivander he/him/his
#
# 	poss	1 head
# 	poss	1 pocket
# 	poss	1 stare
# 	poss	1 shop
#
# 	agent	6 said
# 	agent	2 sold
# 	agent	2 pulled
# 	agent	2 measured
# 	agent	2 snatched
# 	agent	1 moved
# 	agent	1 come
# 	agent	1 touched
# 	agent	1 known
# 	agent	1 shook
#
# 	patient	1 liked
#
# 	mod	1 nose
# 	mod	1 sorry
#
# 350 42 Ronan he/him/his
#
# 	poss	1 head
# 	poss	1 voice
#
# 	agent	5 said
# 	agent	2 stared
# 	agent	2 seen
# 	agent	1 had
# 	agent	1 sighed
# 	agent	1 flung
# 	agent	1 answer
# 	agent	1 repeated
# 	agent	1 took
# 	agent	1 hope
#
# 	patient	1 shoot
# 	patient	1 run
# 	patient	1 watched
# 	patient	1 jus
# 	patient	1 leaving
#
# 	mod	1 centaur
# 	mod	1 well
# 	mod	1 sure
#
# 193 37 George he/him/his
#
# 	poss	1 jokes
# 	poss	1 broom
#
# 	agent	3 said
# 	agent	1 reckons
# 	agent	1 had
# 	agent	1 gave
# 	agent	1 bet
# 	agent	1 came
# 	agent	1 spotted
# 	agent	1 disappeared
# 	agent	1 sent
# 	agent	1 bounded
#
# 	patient	1 heard
# 	patient	1 followed
# 	patient	1 watch
#
#
# 273 36 Filch they/them/their
#
# 	poss	1 voice
# 	poss	1 eyes
# 	poss	1 arm
# 	poss	1 face
#
# 	agent	2 knew
# 	agent	1 found
# 	agent	1 owned
# 	agent	1 pop
# 	agent	1 caught
# 	agent	1 catch
# 	agent	1 enter
# 	agent	1 following
# 	agent	1 tipped
# 	agent	1 running
#
# 	patient	2 tell
# 	patient	1 take
# 	patient	1 passed
#
#
# 354 36 Firenze he/him/his
#
# 	poss	1 legs
# 	poss	1 shoulders
# 	poss	1 head
#
# 	agent	3 said
# 	agent	2 saved
# 	agent	2 done
# 	agent	1 doing
# 	agent	1 have
# 	agent	1 Have
# 	agent	1 thought
# 	agent	1 reared
# 	agent	1 bellowed
# 	agent	1 set
#
# 	patient	1 set
#
# 	mod	1 mule
#
# 279 33 Professor Flitwick he/him/his
#
# 	poss	1 desk
# 	poss	1 pile
# 	poss	1 wand
# 	poss	1 class
# 	poss	1 exam
#
# 	agent	2 put
# 	agent	1 took
# 	agent	1 gave
# 	agent	1 reached
# 	agent	1 appeared
# 	agent	1 hope
# 	agent	1 squeaked
# 	agent	1 said
# 	agent	1 announced
# 	agent	1 thought
#
# 	patient	1 squeaked
# 	patient	1 get
#
# 	mod	1 wizard
# 	mod	1 busy
#
# 268 32 Madam Hooch she/her
#
# 	poss	3 whistle
# 	poss	1 lips
# 	poss	1 face
# 	poss	1 mutter
# 	poss	1 arm
# 	poss	1 broom
# 	poss	1 hand
#
# 	agent	2 told
# 	agent	2 said
# 	agent	1 had
# 	agent	1 barked
# 	agent	1 showed
# 	agent	1 walked
# 	agent	1 blow
# 	agent	1 shouted
# 	agent	1 rising
# 	agent	1 bending
#
# 	patient	1 contact
#
#
# 267 30 Filch he/him/his
#
# 	poss	1 life
# 	poss	1 voice
# 	poss	1 lamp
#
# 	agent	6 said
# 	agent	2 turned
# 	agent	1 asked
# 	agent	1 says
# 	agent	1 help
# 	agent	1 think
# 	agent	1 sounding
# 	agent	1 want
# 	agent	1 suppose
# 	agent	1 added
#
# 	patient	1 Meet
# 	patient	1 Follow
#
# 	mod	2 friendly
# 	mod	1 mistaken
#
# 274 30 Mrs. Norris she/her
#
# 	poss	1 dinner
#
# 	agent	1 patrolled
# 	agent	1 whisk
# 	agent	1 wheezing
# 	agent	1 follows
# 	agent	1 caught
# 	agent	1 gone
# 	agent	1 bet
# 	agent	1 heard
#
# 	patient	1 introduce
# 	patient	1 puts
# 	patient	1 found
# 	patient	1 kick
# 	patient	1 turned
#
#
# 223 28 Goyle he/him/his
#
# 	poss	1 Crabbe
# 	poss	1 Malfoy
# 	poss	1 faces
#
# 	agent	1 reached
# 	agent	1 let
# 	agent	1 swung
# 	agent	1 know
# 	agent	1 open
# 	agent	1 flanked
# 	agent	1 barred
# 	agent	1 chuckled
# 	agent	1 pushed
# 	agent	1 howled
#
# 	patient	1 touched
# 	patient	1 take
# 	patient	1 thrown
#
# 	mod	1 bigger
# 	mod	1 mean
#
# 243 27 Seamus he/him/his
#
# 	poss	1 eye
# 	poss	1 cauldron
# 	poss	1 wand
# 	poss	1 sausages
#
# 	agent	2 said
# 	agent	1 sat
# 	agent	1 interrupted
# 	agent	1 asked
# 	agent	1 winked
# 	agent	1 told
# 	agent	1 swished
# 	agent	1 flicked
# 	agent	1 supposed
# 	agent	1 got
#
# 	patient	1 asked
# 	patient	1 joined
#
# 	mod	1 half
#
# 317 27 Wood he/him/his
#
# 	poss	1 plan
# 	poss	1 spirits
# 	poss	1 side
# 	poss	1 fault
# 	poss	1 talk
#
# 	agent	2 said
# 	agent	1 working
# 	agent	1 becoming
# 	agent	1 gave
# 	agent	1 gotten
# 	agent	1 yelled
# 	agent	1 taken
# 	agent	1 had
# 	agent	1 thundered
# 	agent	1 wins
#
# 	patient	1 ask
# 	patient	1 put
# 	patient	1 stop
#
#
# 204 26 Charlie he/him/his
#
# 	poss	2 letter
# 	poss	1 wand
# 	poss	1 work
# 	poss	1 broom
# 	poss	1 answer
# 	poss	1 friends
#
# 	agent	2 left
# 	agent	1 said
# 	agent	1 played
# 	agent	1 gone
# 	agent	1 got
# 	agent	1 take
# 	agent	1 put
#
# 	patient	1 ask
#
#
# 327 26 Fluffy she/her
#
# 	poss	1 piece
#
# 	agent	1 growling
#
# 	patient	1 knew
# 	patient	1 know
# 	patient	1 borrowed
# 	patient	1 separating
# 	patient	1 playing
#
# 	mod	1 alive
#
# 114 25 Madam Pomfrey she/her
#
# 	poss	1 opinion
# 	poss	1 fussing
#
# 	agent	3 said
# 	agent	2 let
# 	agent	1 liked
# 	agent	1 mended
# 	agent	1 recognize
# 	agent	1 believes
# 	agent	1 came
# 	agent	1 made
# 	agent	1 have
# 	agent	1 felt
#
# 	patient	3 told
# 	patient	1 tell
#
# 	mod	1 woman
#
# 176 22 Quidditch he/him/his
#
#
# 	agent	1 ends
# 	agent	1 lost
#
# 	patient	2 playing
# 	patient	1 follows
# 	patient	1 tent
# 	patient	1 wanted
#
# 	mod	1 easy
#
# 352 22 Bane he/him/his
#
# 	poss	1 legs
#
# 	agent	2 said
# 	agent	1 walked
# 	agent	1 looked
# 	agent	1 thundered
# 	agent	1 kicked
# 	agent	1 see
# 	agent	1 talking
# 	agent	1 thinks
# 	agent	1 stop
#
# 	patient	1 growled
# 	patient	1 leaving
#
# 	mod	1 furious
#
# 110 21 the Muggles they/them/their
#
# 	poss	1 news
#
# 	agent	1 found
# 	agent	1 started
# 	agent	1 say
# 	agent	1 manage
# 	agent	1 forget
#
# 	patient	1 bound
# 	patient	1 wake
# 	patient	1 know
# 	patient	1 stop
# 	patient	1 alarming
#
# 	mod	1 stupid
#
# 222 21 Crabbe they/them/their
#
#
# 	agent	1 flanked
# 	agent	1 said
# 	agent	1 barred
# 	agent	1 chuckled
#
# 	patient	1 take
#
# 	mod	1 bigger
#
# 284 21 Fang he/him/his
#
# 	poss	1 head
# 	poss	1 robes
# 	poss	1 teeth
#
# 	agent	1 looked
# 	agent	1 rested
# 	agent	1 drooled
# 	agent	1 took
# 	agent	1 did
#
# 	patient	1 found
# 	patient	1 want
#
# 	mod	1 fierce
# 	mod	1 coward
#
# 125 20 Mrs. Figg she/her
#
# 	poss	4 leg
# 	poss	1 room
# 	poss	1 crutches
# 	poss	1 cats
#
# 	agent	1 take
# 	agent	1 made
# 	agent	1 owned
# 	agent	1 crossed
# 	agent	1 wasn
# 	agent	1 broken
# 	agent	1 seem
# 	agent	1 let
# 	agent	1 had
#
# 	patient	1 knocked
#
#
# 228 20 Gryffindor she/her
#
#
# 	agent	2 taken
# 	agent	2 goes
# 	agent	1 won
# 	agent	1 had
# 	agent	1 belting
# 	agent	1 scored
#
# 	patient	2 shouted
#
#
# 202 18 the Weasleys they/them/their
#
# 	poss	2 brooms
# 	poss	1 wristwatches
#
# 	agent	1 have
# 	agent	1 afford
# 	agent	1 want
# 	agent	1 flew
# 	agent	1 got
# 	agent	1 dropped
# 	agent	1 circled
# 	agent	1 spent
# 	agent	1 complained
# 	agent	1 stop
#
#
# 	mod	1 more
#
# 166 17 Dean he/him/his
#
# 	poss	1 poster
# 	poss	1 side
#
# 	agent	1 joined
# 	agent	1 yelling
# 	agent	1 talking
# 	agent	1 said
# 	agent	1 shown
#
# 	patient	1 said
# 	patient	1 reminded
#
#
# 116 16 James Potter he/him/his
#
# 	poss	1 son
# 	poss	1 s
#
# 	agent	3 kill
# 	agent	1 tried
#
# 	patient	1 done
# 	patient	1 killed
# 	patient	1 stop
# 	patient	1 kill
#
#
# 133 16 Piers he/him/his
#
# 	poss	1 mother
#
# 	agent	1 sniggered
# 	agent	1 fall
# 	agent	1 wanted
# 	agent	1 swearing
#
# 	patient	1 bought
#
# 	mod	1 boy
# 	mod	1 one
# 	mod	1 big
# 	mod	1 stupid
#
# 142 16 Dudley he/him/his
#
# 	poss	2 mother
# 	poss	1 snores
# 	poss	1 watch
# 	poss	1 wrist
#
# 	agent	1 told
# 	agent	1 jerked
# 	agent	1 said
# 	agent	1 sat
# 	agent	1 squeaked
# 	agent	1 ran
#
# 	patient	1 wake
# 	patient	1 annoy
#
#
# 260 16 the Gryffindors they/them/their
#
# 	poss	1 shoulders
#
# 	agent	1 going
# 	agent	1 came
# 	agent	1 hourglasses
# 	agent	1 thought
# 	agent	1 tied
#
# 	patient	1 flipped
# 	patient	1 point
# 	patient	1 screamed
#
# 	mod	1 beside
#
# 301 16 Malfoy he/him/his
#
# 	poss	2 face
# 	poss	1 eyes
# 	poss	1 elbow
# 	poss	1 rage
# 	poss	1 confusion
#
# 	agent	2 said
# 	agent	1 believe
# 	agent	1 saw
# 	agent	1 seized
# 	agent	1 felt
# 	agent	1 snapped
# 	agent	1 suppose
# 	agent	1 stolen
#
#
#
# 187 15 Hedwig she/her
#
#
# 	agent	2 brought
# 	agent	1 swooping
# 	agent	1 pleased
# 	agent	1 kept
#
# 	patient	2 send
# 	patient	1 call
# 	patient	1 shut
# 	patient	1 put
# 	patient	1 sent
#
#
# 24 14 Gringotts he/him/his
#
#
# 	agent	1 gets
# 	agent	1 trust
# 	agent	1 insisted
# 	agent	1 said
#
# 	patient	1 fer
# 	patient	1 rob
#
#
# 198 14 Lee Jordan he/him/his
#
#
# 	agent	1 go
# 	agent	1 got
# 	agent	1 reckons
# 	agent	1 saying
# 	agent	1 finding
# 	agent	1 commentating
# 	agent	1 shouting
# 	agent	1 tickling
# 	agent	1 left
#
# 	patient	1 revolting
# 	patient	1 warning
#
#
# 261 14 the Slytherins he/him/his
#
# 	poss	1 smiles
#
# 	agent	2 taken
# 	agent	1 got
# 	agent	1 score
# 	agent	1 cheering
# 	agent	1 lost
# 	agent	1 think
# 	agent	1 clapped
# 	agent	1 walked
# 	agent	1 owe
#
#
#
# 174 13 Griphook they/them/their
#
#
# 	agent	4 said
# 	agent	1 held
# 	agent	1 whistled
# 	agent	1 came
# 	agent	1 steering
# 	agent	1 unlocked
# 	agent	1 check
#
# 	patient	1 followed
#
# 	mod	1 goblin
#
# 100 12 the Potters they/them/their
#
# 	poss	1 son
# 	poss	1 kind
#
# 	agent	1 arrived
# 	agent	1 had
# 	agent	1 knew
#
# 	patient	1 keeping
# 	patient	1 related
# 	patient	1 affect
#
#
# 111 12 Dedalus Diggle he/him/his
#
# 	poss	1 name
# 	poss	1 Dedalus
# 	poss	1 hat
#
# 	agent	2 remembers
# 	agent	1 had
# 	agent	1 meeting
# 	agent	1 bowed
# 	agent	1 cried
#
# 	patient	1 tell
# 	patient	1 seen
#
#
# 258 12 Sir Nicholas de Mimsy - Porpington he/him/his
#
# 	poss	1 ear
# 	poss	1 head
# 	poss	1 neck
# 	poss	1 shoulder
#
# 	agent	1 looked
# 	agent	1 wanted
# 	agent	1 said
# 	agent	1 seized
# 	agent	1 pulled
#
# 	patient	1 behead
#
#
# 305 12 the Bludgers they/them/their
#
#
# 	agent	1 do
# 	agent	1 killed
# 	agent	1 crack
#
# 	patient	1 knock
# 	patient	1 keep
#
#
# 199 11 Mom she/her
#
#
# 	agent	1 got
# 	agent	1 tell
#
#
# 	mod	1 witch
#
# 190 10 Ginny she/her
#
#
# 	agent	1 pointing
# 	agent	1 squealed
# 	agent	1 see
#
# 	patient	1 seen
#
# 	mod	1 quiet
#
# 200 10 Percy he/him/his
#
# 	poss	1 rat
#
# 	agent	1 saying
# 	agent	1 said
# 	agent	1 gets
# 	agent	1 left
#
# 	patient	1 kissed
#
# 	mod	2 prefect
#
# 266 10 Ahern he/him/his
#
#
# 	agent	2 go
# 	agent	1 sing
#
# 	patient	1 give
# 	patient	1 remind
# 	patient	1 tell
# 	patient	1 allowed
#
#
# 357 10 Dumbledore he/him/his
#
# 	poss	1 office
#
# 	agent	1 believes
# 	agent	1 lived
#
# 	patient	1 says
# 	patient	1 lets
# 	patient	1 betray
# 	patient	1 stop
# 	patient	1 see
#
#
# 263 9 Great Uncle Algie he/him/his
#
#
# 	agent	2 kept
# 	agent	2 hanging
# 	agent	2 let
# 	agent	1 pushed
# 	agent	1 came
# 	agent	1 bought
#
#
# 	mod	1 pleased
#
# 286 9 Malfay he/him/his
#
# 	poss	1 childhood
# 	poss	1 broomstick
#
# 	agent	1 talk
# 	agent	1 complained
# 	agent	1 told
# 	agent	1 spent
#
# 	patient	1 fight
#
# 	mod	1 way
#
# 295 9 Seeker they/them/their
#
#
# 	agent	1 said
# 	agent	1 win
# 	agent	1 catches
# 	agent	1 playing
# 	agent	1 seen
#
# 	patient	1 playing
#
#
# 205 8 Scabbers he/him/his
#
#
# 	agent	1 stayed
# 	agent	1 hanging
# 	agent	1 fighting
#
# 	patient	1 got
# 	patient	1 brought
#
#
# 115 7 Lily she/her
#
#
#
#
#
# 122 7 Marge she/her
#
# 	poss	1 present
# 	poss	1 ill
#
# 	agent	1 hates
#
# 	patient	1 phone
#
#
# 175 7 Madam Malkin he/him/his
#
# 	poss	2 shop
# 	poss	1 Robes
#
# 	agent	1 stood
# 	agent	1 said
#
#
# 	mod	1 squat
#
# 248 7 Parvati Patil she/her
#
# 	poss	1 friend
#
# 	agent	1 snapped
# 	agent	1 telling
#
# 	patient	1 hugging
#
#
# 259 7 Nearly Headless Nick he/him/his
#
# 	poss	1 head
# 	poss	1 neck
#
# 	agent	2 said
# 	agent	1 flipped
# 	agent	1 hope
# 	agent	1 asked
#
#
# 	mod	1 happy
#
# 112 6 YouKnow - Who he/him/his
#
# 	poss	2 name
#
# 	agent	1 seems
# 	agent	1 gone
#
# 	patient	2 call
#
#
# 153 6 Dumbledore he/him/his
#
# 	poss	1 one
# 	poss	1 orders
#
# 	agent	1 let
#
# 	patient	1 pelts
#
#
# 220 6 Ravenclaw he/him/his
#
#
# 	agent	1 steamrollered
# 	agent	1 has
# 	agent	1 celebrating
#
#
# 	mod	1 bad
#
# 227 6 Trevor he/him/his
#
#
# 	agent	1 cried
# 	agent	1 got
# 	agent	1 raised
# 	agent	1 making
#
# 	patient	1 clutching
# 	patient	1 dropped
#
#
# 289 6 Mr. Ronald Weasley he/him/his
#
# 	poss	1 brothers
#
# 	agent	1 sees
# 	agent	1 standing
#
#
# 	mod	1 relieved
#
# 322 6 the Snitch he/him/his
#
#
# 	agent	1 disappeared
#
# 	patient	1 Send
# 	patient	1 caught
#
#
# 140 5 Mr. H. Potter he/him/his
#
#
# 	agent	1 Scuse
# 	agent	1 made
# 	agent	1 knocked
#
#
#
# 148 5 Dursley he/him/his
#
#
#
# 	patient	1 gave
# 	patient	1 FORBID
#
#
# 150 5 Dear Mr. Potter he/him/his
#
# 	poss	1 owl
#
#
# 	patient	1 inform
# 	patient	1 accepted
#
#
# 152 5 Blimey they/them/their
#
#
#
#
# 	mod	1 solutions
#
# 32 5 Hufflepuff she/her
#
#
# 	agent	1 celebrating
#
#
#
# 181 5 Vol- they/them/their
#
#
#
#
#
# 196 5 Gran she/her
#
#
# 	agent	1 crying
# 	agent	1 knows
# 	agent	1 sent
#
#
# 	mod	1 happy
#
# 203 5 Bill he/him/his
#
# 	poss	1 robes
#
# 	agent	1 left
# 	agent	1 doing
# 	agent	1 used
#
#
# 	mod	1 boy
#
# 221 5 Gloom they/them/their
#
#
# 	agent	1 seemed
# 	agent	1 know
#
# 	patient	1 put
#
#
# 328 5 Mrs. Weasley she/her
#
#
# 	agent	2 said
# 	agent	1 going
# 	agent	1 smiled
#
#
#
# 99 4 Mrs. Potter she/her
#
# 	poss	1 husband
#
# 	agent	1 have
#
#
# 	mod	1 sister
#
# 101 4 Little tyke he/him/his
#
# 	poss	1 money
# 	poss	1 father
#
# 	agent	1 wants
#
#
#
# 105 4 Terry he/him/his
#
#
# 	agent	1 joined
#
# 	patient	1 Going
#
#
# 141 4 Dad he/him/his
#
#
# 	agent	1 got
# 	agent	1 looked
#
#
#
# 206 4 Bettie Bott she/her
#
# 	poss	3 Beans
#
#
#
#
# 232 4 Hannah she/her
#
#
# 	agent	1 went
#
#
#
# 275 4 Professor Sprout they/them/their
#
#
# 	agent	1 say
#
# 	patient	1 had
#
#
# 314 4 Hermlone she/her
#
#
# 	agent	1 conjured
#
# 	patient	1 had
#
#
# 318 4 Chaser Katie Bell of Gryffindor she/her
#
#
# 	agent	1 won
#
# 	patient	1 passes
#
#
# 319 4 Adrian Pucey he/him/his
#
# 	poss	1 way
#
# 	agent	1 ducks
#
# 	patient	1 blocked
#
#
# 325 4 Gryffindor they/them/their
#
#
#
# 	patient	1 kills
#
#
# 334 4 Mr. Nicolas Flamel he/him/his
#
# 	poss	1 birthday
# 	poss	1 wife
#
# 	agent	1 enjoys
#
#
#
# 336 4 the Sorcerer she/her
#
# 	poss	1 Stone
# 	poss	1 St
# 	poss	1 Stones
#
#
#
#
# 339 4 the Stone he/him/his
#
# 	poss	1 's
#
#
# 	patient	1 Call
#
# 	mod	1 safe
#
# 123 3 Mommy they/them/their
#
#
# 	agent	1 forget
#
#
#
# 124 3 Daddy he/him/his
#
#
# 	agent	1 has
#
# 	patient	1 gone
#
#
# 168 3 Doris Crockford they/them/their
#
#
# 	agent	1 believe
# 	agent	1 kept
# 	agent	1 shook
# 	agent	1 led
#
#
#
# 178 3 Hogwarts they/them/their
#
#
# 	agent	1 chose
#
#
#
# 209 3 Agrippa he/him/his
#
#
#
# 	patient	1 missing
# 	patient	1 got
# 	patient	1 get
#
#
# 235 3 Ravenclaws they/them/their
#
#
# 	agent	1 turned
#
# 	patient	1 joined
#
#
# 276 3 Professor Binns they/them/their
#
#
# 	agent	1 droned
# 	agent	1 got
#
#
#
# 297 3 Malfoy'll he/him/his
#
#
# 	agent	1 expected
#
# 	patient	1 punch
#
# 	mod	1 able
#
# 298 3 Malfoys he/him/his
#
#
# 	agent	1 suppose
#
#
#
# 299 3 the Fat Lady he/him/his
#
#
# 	agent	1 gone
# 	agent	1 locked
# 	agent	1 squawked
#
#
#
# 306 3 the Quaffle he/him/his
#
#
#
# 	patient	1 taken
#
#
# 308 3 Seekers they/them/their
#
#
# 	agent	1 get
#
#
# 	mod	1 players
#
# 309 3 Wizard Baruffio he/him/his
#
# 	poss	1 chest
#
# 	agent	1 forget
# 	agent	1 found
#
# 	patient	1 found
#
#
# 324 3 Adrian Pucey he/him/his
#
# 	poss	1 shoulder
# 	poss	1 ear
#
# 	agent	1 dropped
#
#
#
# 329 3 Madam Pince they/them/their
#
#
#
# 	patient	1 ask
#
#
# 104 2 Jim McGuffin he/him/his
#
#
#
#
#
# 127 2 Snowy they/them/their
#
#
#
#
#
# 145 2 Las he/him/his
#
# 	poss	1 time
# 	poss	1 night
#
#
#
#
# 155 2 the Bones he/him/his
#
#
#
#
#
# 170 2 P - P - Potter he/him/his
#
#
# 	agent	1 stammered
#
#
#
# 184 2 Ollivanders he/him/his
#
#
# 	agent	1 left
# 	agent	1 got
#
#
#
# 208 2 Chocolate Frogs he/him/his
#
#
# 	agent	1 have
#
#
#
# 212 2 Morgana he/him/his
#
#
#
# 	patient	1 got
# 	patient	1 had
#
#
# 226 2 Firs they/them/their
#
# 	poss	1 years
#
#
#
#
# 229 2 Friar she/her
#
#
#
#
#
# 233 2 Susan she/her
#
#
# 	agent	1 scuttled
#
#
#
# 247 2 Parkinson he/him/his
#
#
# 	agent	1 said
#
#
#
# 251 2 Professor Quirtell he/him/his
#
#
# 	agent	1 looking
#
# 	patient	1 spotted
#
#
# 264 2 my Great Auntie Enid she/her
#
#
# 	agent	2 offered
#
#
#
# 270 2 Ickle Firsties they/them/their
#
#
#
#
#
# 285 2 Fitch he/him/his
#
#
# 	agent	1 puts
#
# 	patient	1 hear
#
#
# 302 2 Comets they/them/their
#
#
# 	agent	1 look
#
#
#
# 313 2 the Hufflepuffs they/them/their
#
#
# 	agent	1 turned
#
# 	patient	1 joined
#
#
# 316 2 Alicia Spinnet he/him/his
#
#
#
# 	patient	1 passes
#
#
# 333 2 Christmas he/him/his
#
#
#
#
#
# 335 2 Perenelle he/him/his
#
#
#
#
#
# 351 2 Hullo he/him/his
#
#
#
#
#
# 359 2 Mr. Baron he/him/his
#
#
#
#
#
# 360 2 old Peevsie he/him/his
#
# 	poss	1 joke
#
#
# 	patient	1 forgive
#
#
# 361 2 Devil he/him/his
#
# 	poss	2 Snare
